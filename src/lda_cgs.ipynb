# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import time
from lda_cgs import LDA_CGS

# %%
M = 5000
V = 2000
K = 40

# %%
# load and subset data
data = pd.read_csv("../unbounce/data/processed/cleaned_no_apos_2chr_rem.csv")
data = data.sample(M)['cleaned']
# data = data['cleaned']

# %%
vectorizer = CountVectorizer(analyzer = "word",
                             tokenizer = None, 
                             preprocessor = None,
                             stop_words = 'english',
                             max_features = V)
X = vectorizer.fit_transform(data)
# dictionary of word - index pairs
volcabulary_indices_words_dict = dict((v,k) for k,v in vectorizer.vocabulary_.items())

# %%
num_top_words_to_see = 20 # number of keywords to see for each topic
def get_top_words_for_topics(volcabulary_indices_words_dict, topic_word_matrix):
    top_indices_of_topics = np.argsort(topic_word_matrix, axis = 1)[:, np.arange(1, num_top_words_to_see+1)*-1].transpose()
    top_words_of_topics = pd.DataFrame(np.ndarray((num_top_words_to_see, K)))
    for i in range(top_words_of_topics.shape[0]):
        for j in range(top_words_of_topics.shape[1]):
            top_words_of_topics.loc[i, j] = volcabulary_indices_words_dict[top_indices_of_topics[i, j]]
    top_words_of_topics.columns = ["Topic %d"%i for i in range(K)]
    return(top_words_of_topics)

# %%
lda_model = LDA_CGS(K = 40)
lda_model.fit(X)
# Out:
# Initializing variables...

# %%
# K = 40, 43mins
get_top_words_for_topics(volcabulary_indices_words_dict, lda_model.topic_word_matrix_)
# Out:
#         Topic 0    Topic 1     Topic 2       Topic 3   Topic 4   Topic 5  \
# 0      unbounce  community      mobile          form    custom      just
# 1         using       team        page         field    thanks      sure
# 2         error      share     version        fields      just     check
# 3     wordpress       post     content  confirmation     added    update
# 4          does   feedback     desktop        hidden     tried       hey
# 5        simple       help        make        submit   problem      hear
# 6        iframe      happy  responsive      possible    adding     quick
# 7     duplicate    welcome        view         value   default       joe
# 8         shows     things       users        dialog    cheers     hello
# 9         right      reach    browsers         input     hello    wanted
# 10      getting      super     devices      required      case     think
# 11       cheers    shortly       width          able    widget  question
# 12  appreciated      tight      layout     submitted   request    stuart
# 13       easier       hang       built           map    chrome     place
# 14        agree    updates    champion         write    useful   correct
# 15       unless      years      device     correctly   clicked     gives
# 16       plugin    provide    properly         thank     wrong      soon
# 17       slider      touch    versions        string       use      wait
# 18         mark       open        load       mapping     quinn    posted
# 19      stefano      forum      making        filled  thinking   answers
#
#      Topic 6    Topic 7    Topic 8    Topic 9      ...          Topic 30  \
# 0       like       code     google       know      ...              link
# 1       love   unbounce      think        let      ...              want
# 2    awesome       html  analytics    variant      ...              page
# 3    product      forms      track        hey      ...               css
# 4    feature       work     client    article      ...              test
# 5     really      embed    clients   variants      ...            choose
# 6      group       used       know   feedback      ...             works
# 7    helpful       tags   business   actually      ...             party
# 8      tools    options       said       copy      ...              just
# 9        old     create    manager  questions      ...            needed
# 10      easy  recommend     zapier       glad      ...            effect
# 11      know      built     agency    domains      ...         reference
# 12  platform    require        say     answer      ...              note
# 13     color     coding       exit     hotjar      ...              ryan
# 14  feedback    greatly    showing      tests      ...               end
# 15       add   solution       tell     expect      ...        navigation
# 16    groups     insert    digital    michael      ...         attention
# 17   started   standard      goals        new      ...          sections
# 18     plans   provider       fact        tab      ...           limited
# 19   excited  solutions     easier  dashboard      ...             files
#
#      Topic 31   Topic 32      Topic 33       Topic 34     Topic 35  Topic 36  \
# 0      script       need          want           hope       having     video
# 1        text       user    javascript           just      builder      want
# 2         add  different       scripts          helps          hey    people
# 3      change      works          step           like       issues      test
# 4      editor       mind       section           best         able     maybe
# 5    tracking       ways          drop           help         beta      make
# 6     element     social       include      different      browser      goal
# 7        edit       font       preview       question     directly       cta
# 8       event      value        screen          using      support      like
# 9       enter    thought         paste       consider         sign       say
# 10       head       long        jquery        changes       window    likely
# 11      label       copy         users         future      release  campaign
# 12   manually     unique        appear  functionality        going    little
# 13       line      fonts          menu       separate     released      play
# 14  placement        joe      elements      integrate       allows   section
# 15       mark   recently  instructions          wufoo       images    follow
# 16    instead   customer          like     additional  implemented    really
# 17       left       line     implement       requires         save   youtube
# 18      panel     advice       library     completely         news     takes
# 19     inside      guide         boxes    submissions          yes    videos
#
#       Topic 37   Topic 38       Topic 39
# 0          new        use         thanks
# 1         make     domain          great
# 2          way       site           guys
# 3         post      pages            lot
# 4    available      point          going
# 5       better   redirect         justin
# 6    mentioned   existing           good
# 7   salesforce      setup           come
# 8      running       days          makes
# 9      updated        ago          works
# 10         fix      cname  unfortunately
# 11     comment      topic     definitely
# 12    software    setting            big
# 13     missing       host     workaround
# 14      coming     launch        roadmap
# 15       small      hours           said
# 16        ones     record           tool
# 17      shared  subdomain       probably
# 18      change     longer       progress
# 19      taking     change      difficult
#
# [20 rows x 40 columns]

# %%
a = np.array([[0,0], [1,1], [2,2]])

# %%
x,y = a[1,:]

# %%
x
# Out:
# 1
